# %%
from mohan.Similarity import Similarity
from mohan.ColavSimilarity import parse_doi, parse_string
from joblib import Parallel, delayed
import pickle
import numpy as np
from mohan.ColavSimilarity import ColavSimilarity, parse_doi, parse_string
from elasticsearch import Elasticsearch, __version__ as es_version
from sklearn import metrics
import matplotlib.pyplot as plt
import time

# %%
from mohan.ColavSimilarity import ColavSimilarity, parse_string
from elasticsearch import Elasticsearch, __version__ as es_version
from elasticsearch.helpers import bulk


class Similarity:
    def __init__(self, es_index, es_uri: str = "http://localhost:9200",
                 es_auth: tuple = ('elastic', 'colav'),
                 es_req_timeout: int = 120):
        """
        Initialize the Similarity class.
        Parameters:
        -----------
        es_index: str 
                name of the index
        es_uri: str 
                uri of the elastic search server
        es_auth: tuple 
                authentication for the elastic search server
        es_req_timeout: int 
                elastic search request timeout
        """
        auth = es_auth
        if es_version[0] < 8:
            self.es = Elasticsearch(
                es_uri, http_auth=auth, timeout=es_req_timeout)
        else:
            self.es = Elasticsearch(
                es_uri, basic_auth=auth, timeout=es_req_timeout)
        self.es_index = es_index
        self.es_req_timeout = es_req_timeout

    def create_index(self, mapping: dict = None, recreate: bool = False):
        """
        Create an index.
        Parameters:
        -----------
        index_name: str name of the index
        mapping: dict mapping of the index
        recreate: bool whether to recreate the index or not

        """
        if recreate:
            if self.es.indices.exists(index=self.es_index):
                self.delete_index(self.es_index)
        if mapping:
            self.es.indices.create(index=self.es_index, body=mapping)
        else:
            self.es.indices.create(index=self.es_index)

    def delete_index(self, index_name: str):
        """
        Delete an index.
        Parameters:
        -----------
        index_name: str name of the index
        """
        self.es.indices.delete(index=index_name)

    def insert_work(self, _id: str, work: dict):
        """
        Insert a work into the index.
        work should have a dict structure like the next one.
        work = {"title": "title of the work",
                "authors": "authors of the work",
                "source": "source of the work",
                "year": "year of the work",
                "volume": "volume of the work",
                "issue": "issue of the work",
                "page_start": "page start of the work",
                "page_end": "page end of the work"}
        every value is a string, including the year, volume, issue, page_start and page_end.

        Additional fields such as doi, pmid, pmcid, etc. can be added to the work dict if needed,
        but the search is over the previous fields.

        Parameters:
        -----------
        _id: str id of the work (ex: mongodb id as string)
        work: dict work to be inserted
        """
        return self.es.index(index=self.es_index,  id=_id, document=work)

    def search_work(self, title: str, source: str, year: str,
                    volume: str, issue: str, page_start: str, page_end: str, 
                    use_es_thold: bool = False, es_thold_low: int = 10, es_thold_high: int = 120,
                    ratio_thold: int = 90, partial_thold: int = 95, low_thold: int = 80, parse_title: bool = True):
        """
        Compare two papers to know if they are the same or not.
        Parameters:
        -----------
        title: str 
                title of the paper
        source: str 
                name of the journal in which the paper was published
        year: int 
                year in which the paper was published
        volume: int 
                volume of the journal in which the paper was published
        issue: int 
                issue of the journal in which the paper was published
        page_start: int 
                first page of the paper
        page_end: int 
                last page of the paper
        use_es_thold: bool
                whether to use the elastic search score threshold or not
        es_thold_low: int
                elastic search score threshold to discard some results with lower score values
        es_thold_high: int
                elastic search score threshold to return the best hit
        ratio_thold: int 
                threshold to compare through ratio function in thefuzz library
        partial_ratio_thold: int 
                threshold to compare through partial_ratio function in thefuzz library
        low_thold: int
                threshold to discard some results with lower score values
        es_request_timeout: int
                elastic search request timeout
        parse_title: bool
                whether to parse the title or not (parse title helps to improve the results)

        Returns:
        --------
        record: dict when the papers are (potentially) the same, None otherwise.
        """
        if not isinstance(title, str):
            title = ""

        if not isinstance(source, str):
            source = ""

        if isinstance(volume, int):
            volume = str(volume)

        if isinstance(issue, int):
            issue = str(issue)

        if isinstance(page_start, int):
            page_start = str(page_start)

        if isinstance(page_end, int):
            page_end = str(page_end)

        if not isinstance(volume, str):
            volume = ""

        if not isinstance(issue, str):
            issue = ""

        if not isinstance(page_start, str):
            page_start = ""

        if not isinstance(page_end, str):
            page_end = ""
        if parse_title:
            title = parse_string(title)
            
      
        body = {
            "query": {
                "bool": {
                    "should": [
                        {"match": { "title":  {
                                 "query": title,
                                 "operator": "OR"
                              }}},
                        #{"match": {"title": {"query":  title,"boost": 1}}},
                        # {"match": {"source":  source}},
                        { "match": { "source":  {
                                 "query": source,
                                 "operator": "AND"
                              }}},
                        {"term":  {"year": year}},
                        {"term":  {"volume": volume}},
                        {"term":  {"issue": issue}},
                        {"term":  {"page_start": page_start}},
                        {"term":  {"page_end": page_end}},
                    ]
                }
            },
            "size": 20,
        }

        res = self.es.search(index=self.es_index, **body)
        if res["hits"]["total"]["value"] != 0:
            best_hit = res["hits"]["hits"][0]
            if use_es_thold:
                if best_hit["_score"] < es_thold_low:
                    return None
                if best_hit["_score"] >= es_thold_high:
                    return best_hit

            for i in res["hits"]["hits"]:
                value = ColavSimilarity(title, i["_source"]["title"],
                                        source, i["_source"]["source"],
                                        year, i["_source"]["year"],
                                        ratio_thold=ratio_thold, partial_thold=partial_thold, low_thold=low_thold)
                if value:
                    return i
            return None
        else:
            return None

    def insert_bulk(self, entries: list, refresh=True):
        """
        Insert a bulk of works into the index.
        Parameters:
        -----------
        entries: list 
                list of works to be inserted
        """
        return bulk(self.es, entries, index=self.es_index, refresh=refresh, request_timeout=self.es_req_timeout)

# %%
s = Similarity("openalex_parsed",es_uri="172.19.31.8")

# %%
# open a file, where you stored the pickled data
file = open('dataset_full.pkl', 'rb')
# dump information to that file
data = pickle.load(file)
# close the file
file.close()

# %%
hpo=[]
for rt in range(90,100):
    for pt in range(90,100):
        for lt in range(80,85):
            print(f"new opts  rt= {rt} pt={pt} lt={lt}")
            start = time.time()
            opt = {}
            opt["rt"] = rt
            opt["pt"] = pt
            opt["lt"] = lt
            
            fns = []
            fps = []

            for i in range(15):
                if i%5 == 0:
                    print(i)
                scopus = []
                np.random.shuffle(data["p"])
                np.random.shuffle(data["n"])
                for i in data["p"][0:1000]:
                    scopus.append((i,True))
                for i in data["n"][0:1000]:
                    scopus.append((i,False))
                np.random.shuffle(scopus) #shuffle is inplace
                results = Parallel(n_jobs=72,backend='threading',verbose=0)(delayed(s.search_work)(rec[0]['Title'],rec[0]['Source title'],rec[0]['Year'],
                                 rec[0]['Volume'], rec[0]['Issue'], rec[0]['Page start'], rec[0]['Page end'],
                                 use_es_thold = False, es_thold_low = 0, es_thold_high = 180,#) for rec in scopus)
                                 ratio_thold = rt, partial_thold = pt, low_thold = lt) for rec in scopus)
                actual = []
                predicted = []
                for i in range(len(results)):
                    actual.append(scopus[i][1])
                    if results[i] is not None:
                        predicted.append(True)
                    else:
                        predicted.append(False)
                confusion_matrix = metrics.confusion_matrix(actual, predicted)
                confusion_matrix = np.flip(confusion_matrix)
                fn = confusion_matrix[0][1]*100/(confusion_matrix[0][0]+confusion_matrix[0][1])
                fns.append(fn)
                fp = confusion_matrix[1][0]*100/(confusion_matrix[1][0]+confusion_matrix[1][1])
                fps.append(fp)
            opt["fns"] = fns
            opt["fps"] = fps
            hpo.append(opt)
            stop = time.time()
            print(f"run time = {stop-start} sec")
# Out:
# new opts  rt= 90 pt=90 lt=80
# 0
# 5
# 10
# run time = 135.0704004764557 sec
# new opts  rt= 90 pt=90 lt=81
# 0
# 5
# 10
# run time = 135.46503472328186 sec
# new opts  rt= 90 pt=90 lt=82
# 0
# 5
# 10
# run time = 134.83519506454468 sec
# new opts  rt= 90 pt=90 lt=83
# 0
# 5
# 10
# run time = 134.08307147026062 sec
# new opts  rt= 90 pt=90 lt=84
# 0
# 5
# 10
# run time = 135.12980675697327 sec
# new opts  rt= 90 pt=91 lt=80
# 0
# 5
# 10
# run time = 134.96414136886597 sec
# new opts  rt= 90 pt=91 lt=81
# 0
# 5
# 10
# run time = 135.7135729789734 sec
# new opts  rt= 90 pt=91 lt=82
# 0
# 5
# 10
# run time = 134.86275100708008 sec
# new opts  rt= 90 pt=91 lt=83
# 0
# 5
# 10
# run time = 134.68985867500305 sec
# new opts  rt= 90 pt=91 lt=84
# 0
# 5
# 10
# run time = 135.40024399757385 sec
# new opts  rt= 90 pt=92 lt=80
# 0
# 5
# 10
# run time = 135.67176938056946 sec
# new opts  rt= 90 pt=92 lt=81
# 0
# 5
# 10
# run time = 136.32193422317505 sec
# new opts  rt= 90 pt=92 lt=82
# 0
# 5
# 10
# run time = 136.09518718719482 sec
# new opts  rt= 90 pt=92 lt=83
# 0
# 5
# 10
# run time = 136.5523579120636 sec
# new opts  rt= 90 pt=92 lt=84
# 0
# 5
# 10
# run time = 134.9785294532776 sec
# new opts  rt= 90 pt=93 lt=80
# 0
# 5
# 10
# run time = 134.83227586746216 sec
# new opts  rt= 90 pt=93 lt=81
# 0
# 5
# 10
# run time = 135.31957149505615 sec
# new opts  rt= 90 pt=93 lt=82
# 0
# 5
# 10
# run time = 135.05636501312256 sec
# new opts  rt= 90 pt=93 lt=83
# 0
# 5
# 10
# run time = 134.8901331424713 sec
# new opts  rt= 90 pt=93 lt=84
# 0
# 5
# 10
# run time = 136.75621509552002 sec
# new opts  rt= 90 pt=94 lt=80
# 0
# 5
# 10
# run time = 134.99292302131653 sec
# new opts  rt= 90 pt=94 lt=81
# 0
# 5
# 10
# run time = 135.71705150604248 sec
# new opts  rt= 90 pt=94 lt=82
# 0
# 5
# 10
# run time = 134.47105240821838 sec
# new opts  rt= 90 pt=94 lt=83
# 0
# 5
# 10
# run time = 136.46091055870056 sec
# new opts  rt= 90 pt=94 lt=84
# 0
# 5
# 10
# run time = 134.60210037231445 sec
# new opts  rt= 90 pt=95 lt=80
# 0
# 5
# 10
# run time = 134.33327770233154 sec
# new opts  rt= 90 pt=95 lt=81
# 0
# 5
# 10
# run time = 136.18852925300598 sec
# new opts  rt= 90 pt=95 lt=82
# 0
# 5
# 10
# run time = 135.73583936691284 sec
# new opts  rt= 90 pt=95 lt=83
# 0
# 5
# 10
# run time = 135.4349467754364 sec
# new opts  rt= 90 pt=95 lt=84
# 0
# 5
# 10
# run time = 136.35975909233093 sec
# new opts  rt= 90 pt=96 lt=80
# 0
# 5
# 10
# run time = 135.7567663192749 sec
# new opts  rt= 90 pt=96 lt=81
# 0
# 5
# 10
# run time = 135.2137656211853 sec
# new opts  rt= 90 pt=96 lt=82
# 0
# 5
# 10
# run time = 135.18761777877808 sec
# new opts  rt= 90 pt=96 lt=83
# 0
# 5
# 10
# run time = 136.25194001197815 sec
# new opts  rt= 90 pt=96 lt=84
# 0
# 5
# 10
# run time = 136.64679312705994 sec
# new opts  rt= 90 pt=97 lt=80
# 0
# 5
# 10
# run time = 134.8923683166504 sec
# new opts  rt= 90 pt=97 lt=81
# 0
# 5
# 10
# run time = 135.9171905517578 sec
# new opts  rt= 90 pt=97 lt=82
# 0
# 5
# 10
# run time = 134.90433311462402 sec
# new opts  rt= 90 pt=97 lt=83
# 0
# 5
# 10
# run time = 136.31111764907837 sec
# new opts  rt= 90 pt=97 lt=84
# 0
# 5
# 10
# run time = 136.67659497261047 sec
# new opts  rt= 90 pt=98 lt=80
# 0
# 5
# 10
# run time = 135.8717749118805 sec
# new opts  rt= 90 pt=98 lt=81
# 0
# 5
# 10
# run time = 136.41872668266296 sec
# new opts  rt= 90 pt=98 lt=82
# 0
# 5
# 10
# run time = 137.40661144256592 sec
# new opts  rt= 90 pt=98 lt=83
# 0
# 5
# 10
# run time = 136.01035904884338 sec
# new opts  rt= 90 pt=98 lt=84
# 0
# 5
# 10
# run time = 135.66583824157715 sec
# new opts  rt= 90 pt=99 lt=80
# 0
# 5
# 10
# run time = 134.6568787097931 sec
# new opts  rt= 90 pt=99 lt=81
# 0
# 5
# 10
# run time = 135.41657495498657 sec
# new opts  rt= 90 pt=99 lt=82
# 0
# 5
# 10
# run time = 136.4342691898346 sec
# new opts  rt= 90 pt=99 lt=83
# 0
# 5
# 10
# run time = 135.58225345611572 sec
# new opts  rt= 90 pt=99 lt=84
# 0
# 5
# 10
# run time = 135.26280903816223 sec
# new opts  rt= 91 pt=90 lt=80
# 0
# 5
# 10
# run time = 135.13565135002136 sec
# new opts  rt= 91 pt=90 lt=81
# 0
# 5
# 10
# run time = 135.22745013237 sec
# new opts  rt= 91 pt=90 lt=82
# 0
# 5
# 10
# run time = 134.74367666244507 sec
# new opts  rt= 91 pt=90 lt=83
# 0
# 5
# 10
# run time = 136.1060435771942 sec
# new opts  rt= 91 pt=90 lt=84
# 0
# 5
# 10
# run time = 135.53229904174805 sec
# new opts  rt= 91 pt=91 lt=80
# 0
# 5
# 10
# run time = 133.86089825630188 sec
# new opts  rt= 91 pt=91 lt=81
# 0
# 5
# 10
# run time = 134.09675097465515 sec
# new opts  rt= 91 pt=91 lt=82
# 0
# 5
# 10
# run time = 134.6382007598877 sec
# new opts  rt= 91 pt=91 lt=83
# 0
# 5
# 10
# run time = 135.02026271820068 sec
# new opts  rt= 91 pt=91 lt=84
# 0
# 5
# 10
# run time = 134.70587372779846 sec
# new opts  rt= 91 pt=92 lt=80
# 0
# 5
# 10
# run time = 135.4039843082428 sec
# new opts  rt= 91 pt=92 lt=81
# 0
# 5
# 10
# run time = 134.66151762008667 sec
# new opts  rt= 91 pt=92 lt=82
# 0
# 5
# 10
# run time = 134.21903109550476 sec
# new opts  rt= 91 pt=92 lt=83
# 0
# 5
# 10
# run time = 135.36724090576172 sec
# new opts  rt= 91 pt=92 lt=84
# 0
# 5
# 10
# run time = 136.0780107975006 sec
# new opts  rt= 91 pt=93 lt=80
# 0
# 5
# 10
# run time = 134.83644437789917 sec
# new opts  rt= 91 pt=93 lt=81
# 0
# 5
# 10
# run time = 135.91085147857666 sec
# new opts  rt= 91 pt=93 lt=82
# 0
# 5
# 10
# run time = 134.8865315914154 sec
# new opts  rt= 91 pt=93 lt=83
# 0
# 5
# 10
# run time = 134.98783206939697 sec
# new opts  rt= 91 pt=93 lt=84
# 0
# 5
# 10
# run time = 134.21235466003418 sec
# new opts  rt= 91 pt=94 lt=80
# 0
# 5
# 10
# run time = 135.67078018188477 sec
# new opts  rt= 91 pt=94 lt=81
# 0
# 5
# 10
# run time = 135.1363708972931 sec
# new opts  rt= 91 pt=94 lt=82
# 0
# 5
# 10
# run time = 135.8694052696228 sec
# new opts  rt= 91 pt=94 lt=83
# 0
# 5
# 10
# run time = 135.21316480636597 sec
# new opts  rt= 91 pt=94 lt=84
# 0
# 5
# 10
# run time = 134.62603497505188 sec
# new opts  rt= 91 pt=95 lt=80
# 0
# 5
# 10
# run time = 134.44008946418762 sec
# new opts  rt= 91 pt=95 lt=81
# 0
# 5
# 10
# run time = 134.62681651115417 sec
# new opts  rt= 91 pt=95 lt=82
# 0
# 5
# 10
# run time = 134.86921072006226 sec
# new opts  rt= 91 pt=95 lt=83
# 0
# 5
# 10
# run time = 134.89072561264038 sec
# new opts  rt= 91 pt=95 lt=84
# 0
# 5
# 10
# run time = 135.27654457092285 sec
# new opts  rt= 91 pt=96 lt=80
# 0
# 5
# 10
# run time = 134.63733530044556 sec
# new opts  rt= 91 pt=96 lt=81
# 0
# 5
# 10
# run time = 135.64454078674316 sec
# new opts  rt= 91 pt=96 lt=82
# 0
# 5
# 10
# run time = 133.90176844596863 sec
# new opts  rt= 91 pt=96 lt=83
# 0
# 5
# 10
# run time = 132.95510387420654 sec
# new opts  rt= 91 pt=96 lt=84
# 0
# 5
# 10
# run time = 134.3651168346405 sec
# new opts  rt= 91 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.77519130706787 sec
# new opts  rt= 91 pt=97 lt=81
# 0
# 5
# 10
# run time = 132.6884253025055 sec
# new opts  rt= 91 pt=97 lt=82
# 0
# 5
# 10
# run time = 131.71187829971313 sec
# new opts  rt= 91 pt=97 lt=83
# 0
# 5
# 10
# run time = 132.71142077445984 sec
# new opts  rt= 91 pt=97 lt=84
# 0
# 5
# 10
# run time = 133.80926966667175 sec
# new opts  rt= 91 pt=98 lt=80
# 0
# 5
# 10
# run time = 134.5218949317932 sec
# new opts  rt= 91 pt=98 lt=81
# 0
# 5
# 10
# run time = 133.67751622200012 sec
# new opts  rt= 91 pt=98 lt=82
# 0
# 5
# 10
# run time = 132.21521306037903 sec
# new opts  rt= 91 pt=98 lt=83
# 0
# 5
# 10
# run time = 132.288569688797 sec
# new opts  rt= 91 pt=98 lt=84
# 0
# 5
# 10
# run time = 135.16694116592407 sec
# new opts  rt= 91 pt=99 lt=80
# 0
# 5
# 10
# run time = 133.88365173339844 sec
# new opts  rt= 91 pt=99 lt=81
# 0
# 5
# 10
# run time = 132.80936694145203 sec
# new opts  rt= 91 pt=99 lt=82
# 0
# 5
# 10
# run time = 133.91232419013977 sec
# new opts  rt= 91 pt=99 lt=83
# 0
# 5
# 10
# run time = 132.9697494506836 sec
# new opts  rt= 91 pt=99 lt=84
# 0
# 5
# 10
# run time = 133.2015905380249 sec
# new opts  rt= 92 pt=90 lt=80
# 0
# 5
# 10
# run time = 133.90016078948975 sec
# new opts  rt= 92 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.1632378101349 sec
# new opts  rt= 92 pt=90 lt=82
# 0
# 5
# 10
# run time = 132.00772643089294 sec
# new opts  rt= 92 pt=90 lt=83
# 0
# 5
# 10
# run time = 132.2584855556488 sec
# new opts  rt= 92 pt=90 lt=84
# 0
# 5
# 10
# run time = 132.70727133750916 sec
# new opts  rt= 92 pt=91 lt=80
# 0
# 5
# 10
# run time = 133.54918313026428 sec
# new opts  rt= 92 pt=91 lt=81
# 0
# 5
# 10
# run time = 132.10632038116455 sec
# new opts  rt= 92 pt=91 lt=82
# 0
# 5
# 10
# run time = 132.57314443588257 sec
# new opts  rt= 92 pt=91 lt=83
# 0
# 5
# 10
# run time = 132.41762042045593 sec
# new opts  rt= 92 pt=91 lt=84
# 0
# 5
# 10
# run time = 131.83964228630066 sec
# new opts  rt= 92 pt=92 lt=80
# 0
# 5
# 10
# run time = 133.167147397995 sec
# new opts  rt= 92 pt=92 lt=81
# 0
# 5
# 10
# run time = 132.38872909545898 sec
# new opts  rt= 92 pt=92 lt=82
# 0
# 5
# 10
# run time = 132.17476606369019 sec
# new opts  rt= 92 pt=92 lt=83
# 0
# 5
# 10
# run time = 132.12836027145386 sec
# new opts  rt= 92 pt=92 lt=84
# 0
# 5
# 10
# run time = 134.00299739837646 sec
# new opts  rt= 92 pt=93 lt=80
# 0
# 5
# 10
# run time = 130.6444754600525 sec
# new opts  rt= 92 pt=93 lt=81
# 0
# 5
# 10
# run time = 132.33818221092224 sec
# new opts  rt= 92 pt=93 lt=82
# 0
# 5
# 10
# run time = 132.81572651863098 sec
# new opts  rt= 92 pt=93 lt=83
# 0
# 5
# 10
# run time = 131.41643643379211 sec
# new opts  rt= 92 pt=93 lt=84
# 0
# 5
# 10
# run time = 132.05712461471558 sec
# new opts  rt= 92 pt=94 lt=80
# 0
# 5
# 10
# run time = 133.0003480911255 sec
# new opts  rt= 92 pt=94 lt=81
# 0
# 5
# 10
# run time = 131.75828790664673 sec
# new opts  rt= 92 pt=94 lt=82
# 0
# 5
# 10
# run time = 132.7351086139679 sec
# new opts  rt= 92 pt=94 lt=83
# 0
# 5
# 10
# run time = 133.4049847126007 sec
# new opts  rt= 92 pt=94 lt=84
# 0
# 5
# 10
# run time = 132.95392298698425 sec
# new opts  rt= 92 pt=95 lt=80
# 0
# 5
# 10
# run time = 132.73033690452576 sec
# new opts  rt= 92 pt=95 lt=81
# 0
# 5
# 10
# run time = 133.0289831161499 sec
# new opts  rt= 92 pt=95 lt=82
# 0
# 5
# 10
# run time = 133.6453275680542 sec
# new opts  rt= 92 pt=95 lt=83
# 0
# 5
# 10
# run time = 133.19871354103088 sec
# new opts  rt= 92 pt=95 lt=84
# 0
# 5
# 10
# run time = 132.8467037677765 sec
# new opts  rt= 92 pt=96 lt=80
# 0
# 5
# 10
# run time = 131.42614603042603 sec
# new opts  rt= 92 pt=96 lt=81
# 0
# 5
# 10
# run time = 133.63026690483093 sec
# new opts  rt= 92 pt=96 lt=82
# 0
# 5
# 10
# run time = 133.17584776878357 sec
# new opts  rt= 92 pt=96 lt=83
# 0
# 5
# 10
# run time = 133.17648077011108 sec
# new opts  rt= 92 pt=96 lt=84
# 0
# 5
# 10
# run time = 132.9491159915924 sec
# new opts  rt= 92 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.69202589988708 sec
# new opts  rt= 92 pt=97 lt=81
# 0
# 5
# 10
# run time = 132.42787766456604 sec
# new opts  rt= 92 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.33095264434814 sec
# new opts  rt= 92 pt=97 lt=83
# 0
# 5
# 10
# run time = 132.21868515014648 sec
# new opts  rt= 92 pt=97 lt=84
# 0
# 5
# 10
# run time = 131.44966864585876 sec
# new opts  rt= 92 pt=98 lt=80
# 0
# 5
# 10
# run time = 132.7867398262024 sec
# new opts  rt= 92 pt=98 lt=81
# 0
# 5
# 10
# run time = 132.384202003479 sec
# new opts  rt= 92 pt=98 lt=82
# 0
# 5
# 10
# run time = 132.83911681175232 sec
# new opts  rt= 92 pt=98 lt=83
# 0
# 5
# 10
# run time = 132.82928586006165 sec
# new opts  rt= 92 pt=98 lt=84
# 0
# 5
# 10
# run time = 133.44468879699707 sec
# new opts  rt= 92 pt=99 lt=80
# 0
# 5
# 10
# run time = 132.33865213394165 sec
# new opts  rt= 92 pt=99 lt=81
# 0
# 5
# 10
# run time = 133.03239798545837 sec
# new opts  rt= 92 pt=99 lt=82
# 0
# 5
# 10
# run time = 133.07209157943726 sec
# new opts  rt= 92 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.8131217956543 sec
# new opts  rt= 92 pt=99 lt=84
# 0
# 5
# 10
# run time = 134.268404006958 sec
# new opts  rt= 93 pt=90 lt=80
# 0
# 5
# 10
# run time = 132.55985260009766 sec
# new opts  rt= 93 pt=90 lt=81
# 0
# 5
# 10
# run time = 133.2176067829132 sec
# new opts  rt= 93 pt=90 lt=82
# 0
# 5
# 10
# run time = 131.77237820625305 sec
# new opts  rt= 93 pt=90 lt=83
# 0
# 5
# 10
# run time = 132.8865261077881 sec
# new opts  rt= 93 pt=90 lt=84
# 0
# 5
# 10
# run time = 133.90606808662415 sec
# new opts  rt= 93 pt=91 lt=80
# 0
# 5
# 10
# run time = 131.8183183670044 sec
# new opts  rt= 93 pt=91 lt=81
# 0
# 5
# 10
# run time = 132.67029309272766 sec
# new opts  rt= 93 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.22559595108032 sec
# new opts  rt= 93 pt=91 lt=83
# 0
# 5
# 10
# run time = 133.42068910598755 sec
# new opts  rt= 93 pt=91 lt=84
# 0
# 5
# 10
# run time = 131.82589554786682 sec
# new opts  rt= 93 pt=92 lt=80
# 0
# 5
# 10
# run time = 132.22901582717896 sec
# new opts  rt= 93 pt=92 lt=81
# 0
# 5
# 10
# run time = 133.1155288219452 sec
# new opts  rt= 93 pt=92 lt=82
# 0
# 5
# 10
# run time = 131.83044123649597 sec
# new opts  rt= 93 pt=92 lt=83
# 0
# 5
# 10
# run time = 133.4130392074585 sec
# new opts  rt= 93 pt=92 lt=84
# 0
# 5
# 10
# run time = 134.0391764640808 sec
# new opts  rt= 93 pt=93 lt=80
# 0
# 5
# 10
# run time = 132.96637725830078 sec
# new opts  rt= 93 pt=93 lt=81
# 0
# 5
# 10
# run time = 133.4057354927063 sec
# new opts  rt= 93 pt=93 lt=82
# 0
# 5
# 10
# run time = 133.33728456497192 sec
# new opts  rt= 93 pt=93 lt=83
# 0
# 5
# 10
# run time = 132.81379461288452 sec
# new opts  rt= 93 pt=93 lt=84
# 0
# 5
# 10
# run time = 132.6158800125122 sec
# new opts  rt= 93 pt=94 lt=80
# 0
# 5
# 10
# run time = 134.08638429641724 sec
# new opts  rt= 93 pt=94 lt=81
# 0
# 5
# 10
# run time = 132.7798547744751 sec
# new opts  rt= 93 pt=94 lt=82
# 0
# 5
# 10
# run time = 133.88883233070374 sec
# new opts  rt= 93 pt=94 lt=83
# 0
# 5
# 10
# run time = 133.08753871917725 sec
# new opts  rt= 93 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.9709255695343 sec
# new opts  rt= 93 pt=95 lt=80
# 0
# 5
# 10
# run time = 133.17847990989685 sec
# new opts  rt= 93 pt=95 lt=81
# 0
# 5
# 10
# run time = 133.7931604385376 sec
# new opts  rt= 93 pt=95 lt=82
# 0
# 5
# 10
# run time = 132.84462594985962 sec
# new opts  rt= 93 pt=95 lt=83
# 0
# 5
# 10
# run time = 133.48321509361267 sec
# new opts  rt= 93 pt=95 lt=84
# 0
# 5
# 10
# run time = 132.7362687587738 sec
# new opts  rt= 93 pt=96 lt=80
# 0
# 5
# 10
# run time = 132.69884538650513 sec
# new opts  rt= 93 pt=96 lt=81
# 0
# 5
# 10
# run time = 132.54854035377502 sec
# new opts  rt= 93 pt=96 lt=82
# 0
# 5
# 10
# run time = 133.89349913597107 sec
# new opts  rt= 93 pt=96 lt=83
# 0
# 5
# 10
# run time = 133.84744000434875 sec
# new opts  rt= 93 pt=96 lt=84
# 0
# 5
# 10
# run time = 136.0648274421692 sec
# new opts  rt= 93 pt=97 lt=80
# 0
# 5
# 10
# run time = 134.45778918266296 sec
# new opts  rt= 93 pt=97 lt=81
# 0
# 5
# 10
# run time = 133.99422359466553 sec
# new opts  rt= 93 pt=97 lt=82
# 0
# 5
# 10
# run time = 134.03243255615234 sec
# new opts  rt= 93 pt=97 lt=83
# 0
# 5
# 10
# run time = 134.20725536346436 sec
# new opts  rt= 93 pt=97 lt=84
# 0
# 5
# 10
# run time = 134.0189769268036 sec
# new opts  rt= 93 pt=98 lt=80
# 0
# 5
# 10
# run time = 134.07522225379944 sec
# new opts  rt= 93 pt=98 lt=81
# 0
# 5
# 10
# run time = 134.64564442634583 sec
# new opts  rt= 93 pt=98 lt=82
# 0
# 5
# 10
# run time = 133.60298824310303 sec
# new opts  rt= 93 pt=98 lt=83
# 0
# 5
# 10
# run time = 133.92927646636963 sec
# new opts  rt= 93 pt=98 lt=84
# 0
# 5
# 10
# run time = 135.61973237991333 sec
# new opts  rt= 93 pt=99 lt=80
# 0
# 5
# 10
# run time = 134.31387782096863 sec
# new opts  rt= 93 pt=99 lt=81
# 0
# 5
# 10
# run time = 133.92888140678406 sec
# new opts  rt= 93 pt=99 lt=82
# 0
# 5
# 10
# run time = 136.62745022773743 sec
# new opts  rt= 93 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.89607119560242 sec
# new opts  rt= 93 pt=99 lt=84
# 0
# 5
# 10
# run time = 133.5582537651062 sec
# new opts  rt= 94 pt=90 lt=80
# 0
# 5
# 10
# run time = 133.6830325126648 sec
# new opts  rt= 94 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.90151071548462 sec
# new opts  rt= 94 pt=90 lt=82
# 0
# 5
# 10
# run time = 132.65361547470093 sec
# new opts  rt= 94 pt=90 lt=83
# 0
# 5
# 10
# run time = 133.18554639816284 sec
# new opts  rt= 94 pt=90 lt=84
# 0
# 5
# 10
# run time = 131.73831009864807 sec
# new opts  rt= 94 pt=91 lt=80
# 0
# 5
# 10
# run time = 133.01429629325867 sec
# new opts  rt= 94 pt=91 lt=81
# 0
# 5
# 10
# run time = 134.12229084968567 sec
# new opts  rt= 94 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.21483397483826 sec
# new opts  rt= 94 pt=91 lt=83
# 0
# 5
# 10
# run time = 134.23252487182617 sec
# new opts  rt= 94 pt=91 lt=84
# 0
# 5
# 10
# run time = 133.26657390594482 sec
# new opts  rt= 94 pt=92 lt=80
# 0
# 5
# 10
# run time = 133.1481318473816 sec
# new opts  rt= 94 pt=92 lt=81
# 0
# 5
# 10
# run time = 133.9958245754242 sec
# new opts  rt= 94 pt=92 lt=82
# 0
# 5
# 10
# run time = 132.57812523841858 sec
# new opts  rt= 94 pt=92 lt=83
# 0
# 5
# 10
# run time = 133.42345762252808 sec
# new opts  rt= 94 pt=92 lt=84
# 0
# 5
# 10
# run time = 131.95201230049133 sec
# new opts  rt= 94 pt=93 lt=80
# 0
# 5
# 10
# run time = 132.3818395137787 sec
# new opts  rt= 94 pt=93 lt=81
# 0
# 5
# 10
# run time = 133.2196991443634 sec
# new opts  rt= 94 pt=93 lt=82
# 0
# 5
# 10
# run time = 132.48041081428528 sec
# new opts  rt= 94 pt=93 lt=83
# 0
# 5
# 10
# run time = 131.97321963310242 sec
# new opts  rt= 94 pt=93 lt=84
# 0
# 5
# 10
# run time = 133.86962819099426 sec
# new opts  rt= 94 pt=94 lt=80
# 0
# 5
# 10
# run time = 134.36698627471924 sec
# new opts  rt= 94 pt=94 lt=81
# 0
# 5
# 10
# run time = 136.05738639831543 sec
# new opts  rt= 94 pt=94 lt=82
# 0
# 5
# 10
# run time = 134.64065265655518 sec
# new opts  rt= 94 pt=94 lt=83
# 0
# 5
# 10
# run time = 133.10721492767334 sec
# new opts  rt= 94 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.2763795852661 sec
# new opts  rt= 94 pt=95 lt=80
# 0
# 5
# 10
# run time = 133.76136708259583 sec
# new opts  rt= 94 pt=95 lt=81
# 0
# 5
# 10
# run time = 134.3711462020874 sec
# new opts  rt= 94 pt=95 lt=82
# 0
# 5
# 10
# run time = 133.44246220588684 sec
# new opts  rt= 94 pt=95 lt=83
# 0
# 5
# 10
# run time = 132.6349527835846 sec
# new opts  rt= 94 pt=95 lt=84
# 0
# 5
# 10
# run time = 132.96669840812683 sec
# new opts  rt= 94 pt=96 lt=80
# 0
# 5
# 10
# run time = 132.57618045806885 sec
# new opts  rt= 94 pt=96 lt=81
# 0
# 5
# 10
# run time = 133.40720963478088 sec
# new opts  rt= 94 pt=96 lt=82
# 0
# 5
# 10
# run time = 133.3954782485962 sec
# new opts  rt= 94 pt=96 lt=83
# 0
# 5
# 10
# run time = 131.0895209312439 sec
# new opts  rt= 94 pt=96 lt=84
# 0
# 5
# 10
# run time = 132.28719472885132 sec
# new opts  rt= 94 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.6233344078064 sec
# new opts  rt= 94 pt=97 lt=81
# 0
# 5
# 10
# run time = 132.4068865776062 sec
# new opts  rt= 94 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.76188683509827 sec
# new opts  rt= 94 pt=97 lt=83
# 0
# 5
# 10
# run time = 133.367778301239 sec
# new opts  rt= 94 pt=97 lt=84
# 0
# 5
# 10
# run time = 133.21947360038757 sec
# new opts  rt= 94 pt=98 lt=80
# 0
# 5
# 10
# run time = 132.76779222488403 sec
# new opts  rt= 94 pt=98 lt=81
# 0
# 5
# 10
# run time = 132.5529706478119 sec
# new opts  rt= 94 pt=98 lt=82
# 0
# 5
# 10
# run time = 132.85934257507324 sec
# new opts  rt= 94 pt=98 lt=83
# 0
# 5
# 10
# run time = 132.5672309398651 sec
# new opts  rt= 94 pt=98 lt=84
# 0
# 5
# 10
# run time = 133.64921116828918 sec
# new opts  rt= 94 pt=99 lt=80
# 0
# 5
# 10
# run time = 132.8869206905365 sec
# new opts  rt= 94 pt=99 lt=81
# 0
# 5
# 10
# run time = 132.77824640274048 sec
# new opts  rt= 94 pt=99 lt=82
# 0
# 5
# 10
# run time = 133.0304720401764 sec
# new opts  rt= 94 pt=99 lt=83
# 0
# 5
# 10
# run time = 132.88112235069275 sec
# new opts  rt= 94 pt=99 lt=84
# 0
# 5
# 10
# run time = 133.05079340934753 sec
# new opts  rt= 95 pt=90 lt=80
# 0
# 5
# 10
# run time = 132.9352581501007 sec
# new opts  rt= 95 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.4964370727539 sec
# new opts  rt= 95 pt=90 lt=82
# 0
# 5
# 10
# run time = 132.341717004776 sec
# new opts  rt= 95 pt=90 lt=83
# 0
# 5
# 10
# run time = 131.9547302722931 sec
# new opts  rt= 95 pt=90 lt=84
# 0
# 5
# 10
# run time = 131.28162384033203 sec
# new opts  rt= 95 pt=91 lt=80
# 0
# 5
# 10
# run time = 132.01662063598633 sec
# new opts  rt= 95 pt=91 lt=81
# 0
# 5
# 10
# run time = 132.92926168441772 sec
# new opts  rt= 95 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.18534541130066 sec
# new opts  rt= 95 pt=91 lt=83
# 0
# 5
# 10
# run time = 132.3585548400879 sec
# new opts  rt= 95 pt=91 lt=84
# 0
# 5
# 10
# run time = 132.30368828773499 sec
# new opts  rt= 95 pt=92 lt=80
# 0
# 5
# 10
# run time = 132.49498867988586 sec
# new opts  rt= 95 pt=92 lt=81
# 0
# 5
# 10
# run time = 133.15878176689148 sec
# new opts  rt= 95 pt=92 lt=82
# 0
# 5
# 10
# run time = 133.3713355064392 sec
# new opts  rt= 95 pt=92 lt=83
# 0
# 5
# 10
# run time = 132.53075194358826 sec
# new opts  rt= 95 pt=92 lt=84
# 0
# 5
# 10
# run time = 132.34154391288757 sec
# new opts  rt= 95 pt=93 lt=80
# 0
# 5
# 10
# run time = 132.60624933242798 sec
# new opts  rt= 95 pt=93 lt=81
# 0
# 5
# 10
# run time = 132.20643544197083 sec
# new opts  rt= 95 pt=93 lt=82
# 0
# 5
# 10
# run time = 133.99268698692322 sec
# new opts  rt= 95 pt=93 lt=83
# 0
# 5
# 10
# run time = 132.3004970550537 sec
# new opts  rt= 95 pt=93 lt=84
# 0
# 5
# 10
# run time = 132.86733198165894 sec
# new opts  rt= 95 pt=94 lt=80
# 0
# 5
# 10
# run time = 132.06183791160583 sec
# new opts  rt= 95 pt=94 lt=81
# 0
# 5
# 10
# run time = 133.16017031669617 sec
# new opts  rt= 95 pt=94 lt=82
# 0
# 5
# 10
# run time = 133.44906544685364 sec
# new opts  rt= 95 pt=94 lt=83
# 0
# 5
# 10
# run time = 133.5602798461914 sec
# new opts  rt= 95 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.27456092834473 sec
# new opts  rt= 95 pt=95 lt=80
# 0
# 5
# 10
# run time = 131.9885392189026 sec
# new opts  rt= 95 pt=95 lt=81
# 0
# 5
# 10
# run time = 132.49477338790894 sec
# new opts  rt= 95 pt=95 lt=82
# 0
# 5
# 10
# run time = 132.91668248176575 sec
# new opts  rt= 95 pt=95 lt=83
# 0
# 5
# 10
# run time = 133.22287249565125 sec
# new opts  rt= 95 pt=95 lt=84
# 0
# 5
# 10
# run time = 133.96301198005676 sec
# new opts  rt= 95 pt=96 lt=80
# 0
# 5
# 10
# run time = 133.6713318824768 sec
# new opts  rt= 95 pt=96 lt=81
# 0
# 5
# 10
# run time = 132.7026801109314 sec
# new opts  rt= 95 pt=96 lt=82
# 0
# 5
# 10
# run time = 131.7770767211914 sec
# new opts  rt= 95 pt=96 lt=83
# 0
# 5
# 10
# run time = 134.36610198020935 sec
# new opts  rt= 95 pt=96 lt=84
# 0
# 5
# 10
# run time = 132.345144033432 sec
# new opts  rt= 95 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.94057369232178 sec
# new opts  rt= 95 pt=97 lt=81
# 0
# 5
# 10
# run time = 132.31961631774902 sec
# new opts  rt= 95 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.12410163879395 sec
# new opts  rt= 95 pt=97 lt=83
# 0
# 5
# 10
# run time = 133.6875729560852 sec
# new opts  rt= 95 pt=97 lt=84
# 0
# 5
# 10
# run time = 132.55953335762024 sec
# new opts  rt= 95 pt=98 lt=80
# 0
# 5
# 10
# run time = 134.30929470062256 sec
# new opts  rt= 95 pt=98 lt=81
# 0
# 5
# 10
# run time = 133.00865507125854 sec
# new opts  rt= 95 pt=98 lt=82
# 0
# 5
# 10
# run time = 133.3207812309265 sec
# new opts  rt= 95 pt=98 lt=83
# 0
# 5
# 10
# run time = 132.80922937393188 sec
# new opts  rt= 95 pt=98 lt=84
# 0
# 5
# 10
# run time = 132.63700032234192 sec
# new opts  rt= 95 pt=99 lt=80
# 0
# 5
# 10
# run time = 133.45981621742249 sec
# new opts  rt= 95 pt=99 lt=81
# 0
# 5
# 10
# run time = 132.60558319091797 sec
# new opts  rt= 95 pt=99 lt=82
# 0
# 5
# 10
# run time = 132.93693232536316 sec
# new opts  rt= 95 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.16571617126465 sec
# new opts  rt= 95 pt=99 lt=84
# 0
# 5
# 10
# run time = 131.48133635520935 sec
# new opts  rt= 96 pt=90 lt=80
# 0
# 5
# 10
# run time = 133.31177878379822 sec
# new opts  rt= 96 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.26961660385132 sec
# new opts  rt= 96 pt=90 lt=82
# 0
# 5
# 10
# run time = 132.81052660942078 sec
# new opts  rt= 96 pt=90 lt=83
# 0
# 5
# 10
# run time = 133.60356950759888 sec
# new opts  rt= 96 pt=90 lt=84
# 0
# 5
# 10
# run time = 133.11205315589905 sec
# new opts  rt= 96 pt=91 lt=80
# 0
# 5
# 10
# run time = 132.6392366886139 sec
# new opts  rt= 96 pt=91 lt=81
# 0
# 5
# 10
# run time = 133.47215104103088 sec
# new opts  rt= 96 pt=91 lt=82
# 0
# 5
# 10
# run time = 132.31326270103455 sec
# new opts  rt= 96 pt=91 lt=83
# 0
# 5
# 10
# run time = 132.29601407051086 sec
# new opts  rt= 96 pt=91 lt=84
# 0
# 5
# 10
# run time = 133.4482295513153 sec
# new opts  rt= 96 pt=92 lt=80
# 0
# 5
# 10
# run time = 133.138525724411 sec
# new opts  rt= 96 pt=92 lt=81
# 0
# 5
# 10
# run time = 133.85338044166565 sec
# new opts  rt= 96 pt=92 lt=82
# 0
# 5
# 10
# run time = 131.9442698955536 sec
# new opts  rt= 96 pt=92 lt=83
# 0
# 5
# 10
# run time = 133.31312012672424 sec
# new opts  rt= 96 pt=92 lt=84
# 0
# 5
# 10
# run time = 131.74244379997253 sec
# new opts  rt= 96 pt=93 lt=80
# 0
# 5
# 10
# run time = 134.45295548439026 sec
# new opts  rt= 96 pt=93 lt=81
# 0
# 5
# 10
# run time = 131.68766856193542 sec
# new opts  rt= 96 pt=93 lt=82
# 0
# 5
# 10
# run time = 133.02709412574768 sec
# new opts  rt= 96 pt=93 lt=83
# 0
# 5
# 10
# run time = 132.26344394683838 sec
# new opts  rt= 96 pt=93 lt=84
# 0
# 5
# 10
# run time = 131.8564953804016 sec
# new opts  rt= 96 pt=94 lt=80
# 0
# 5
# 10
# run time = 133.48601365089417 sec
# new opts  rt= 96 pt=94 lt=81
# 0
# 5
# 10
# run time = 133.14528965950012 sec
# new opts  rt= 96 pt=94 lt=82
# 0
# 5
# 10
# run time = 132.88864254951477 sec
# new opts  rt= 96 pt=94 lt=83
# 0
# 5
# 10
# run time = 132.93279576301575 sec
# new opts  rt= 96 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.08186769485474 sec
# new opts  rt= 96 pt=95 lt=80
# 0
# 5
# 10
# run time = 131.27496242523193 sec
# new opts  rt= 96 pt=95 lt=81
# 0
# 5
# 10
# run time = 133.13235187530518 sec
# new opts  rt= 96 pt=95 lt=82
# 0
# 5
# 10
# run time = 131.5218677520752 sec
# new opts  rt= 96 pt=95 lt=83
# 0
# 5
# 10
# run time = 132.77812242507935 sec
# new opts  rt= 96 pt=95 lt=84
# 0
# 5
# 10
# run time = 133.84142065048218 sec
# new opts  rt= 96 pt=96 lt=80
# 0
# 5
# 10
# run time = 134.23759508132935 sec
# new opts  rt= 96 pt=96 lt=81
# 0
# 5
# 10
# run time = 132.94103813171387 sec
# new opts  rt= 96 pt=96 lt=82
# 0
# 5
# 10
# run time = 133.79854488372803 sec
# new opts  rt= 96 pt=96 lt=83
# 0
# 5
# 10
# run time = 133.5050048828125 sec
# new opts  rt= 96 pt=96 lt=84
# 0
# 5
# 10
# run time = 133.9114863872528 sec
# new opts  rt= 96 pt=97 lt=80
# 0
# 5
# 10
# run time = 131.41386723518372 sec
# new opts  rt= 96 pt=97 lt=81
# 0
# 5
# 10
# run time = 133.09567403793335 sec
# new opts  rt= 96 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.09411787986755 sec
# new opts  rt= 96 pt=97 lt=83
# 0
# 5
# 10
# run time = 132.7443597316742 sec
# new opts  rt= 96 pt=97 lt=84
# 0
# 5
# 10
# run time = 132.3703429698944 sec
# new opts  rt= 96 pt=98 lt=80
# 0
# 5
# 10
# run time = 133.63080978393555 sec
# new opts  rt= 96 pt=98 lt=81
# 0
# 5
# 10
# run time = 133.19134068489075 sec
# new opts  rt= 96 pt=98 lt=82
# 0
# 5
# 10
# run time = 132.8949739933014 sec
# new opts  rt= 96 pt=98 lt=83
# 0
# 5
# 10
# run time = 132.84067964553833 sec
# new opts  rt= 96 pt=98 lt=84
# 0
# 5
# 10
# run time = 134.48090744018555 sec
# new opts  rt= 96 pt=99 lt=80
# 0
# 5
# 10
# run time = 133.06038355827332 sec
# new opts  rt= 96 pt=99 lt=81
# 0
# 5
# 10
# run time = 133.3867642879486 sec
# new opts  rt= 96 pt=99 lt=82
# 0
# 5
# 10
# run time = 132.48879098892212 sec
# new opts  rt= 96 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.5397708415985 sec
# new opts  rt= 96 pt=99 lt=84
# 0
# 5
# 10
# run time = 132.24620079994202 sec
# new opts  rt= 97 pt=90 lt=80
# 0
# 5
# 10
# run time = 131.81013536453247 sec
# new opts  rt= 97 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.3878607749939 sec
# new opts  rt= 97 pt=90 lt=82
# 0
# 5
# 10
# run time = 131.41471910476685 sec
# new opts  rt= 97 pt=90 lt=83
# 0
# 5
# 10
# run time = 133.22298407554626 sec
# new opts  rt= 97 pt=90 lt=84
# 0
# 5
# 10
# run time = 132.66549062728882 sec
# new opts  rt= 97 pt=91 lt=80
# 0
# 5
# 10
# run time = 132.3882279396057 sec
# new opts  rt= 97 pt=91 lt=81
# 0
# 5
# 10
# run time = 131.71521496772766 sec
# new opts  rt= 97 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.4668779373169 sec
# new opts  rt= 97 pt=91 lt=83
# 0
# 5
# 10
# run time = 133.19291067123413 sec
# new opts  rt= 97 pt=91 lt=84
# 0
# 5
# 10
# run time = 132.56474018096924 sec
# new opts  rt= 97 pt=92 lt=80
# 0
# 5
# 10
# run time = 132.24117159843445 sec
# new opts  rt= 97 pt=92 lt=81
# 0
# 5
# 10
# run time = 133.80705618858337 sec
# new opts  rt= 97 pt=92 lt=82
# 0
# 5
# 10
# run time = 132.86446571350098 sec
# new opts  rt= 97 pt=92 lt=83
# 0
# 5
# 10
# run time = 133.55331087112427 sec
# new opts  rt= 97 pt=92 lt=84
# 0
# 5
# 10
# run time = 132.75459551811218 sec
# new opts  rt= 97 pt=93 lt=80
# 0
# 5
# 10
# run time = 134.11658096313477 sec
# new opts  rt= 97 pt=93 lt=81
# 0
# 5
# 10
# run time = 133.27270102500916 sec
# new opts  rt= 97 pt=93 lt=82
# 0
# 5
# 10
# run time = 131.73829078674316 sec
# new opts  rt= 97 pt=93 lt=83
# 0
# 5
# 10
# run time = 133.0011341571808 sec
# new opts  rt= 97 pt=93 lt=84
# 0
# 5
# 10
# run time = 133.3920693397522 sec
# new opts  rt= 97 pt=94 lt=80
# 0
# 5
# 10
# run time = 133.00576090812683 sec
# new opts  rt= 97 pt=94 lt=81
# 0
# 5
# 10
# run time = 132.9115662574768 sec
# new opts  rt= 97 pt=94 lt=82
# 0
# 5
# 10
# run time = 132.46439814567566 sec
# new opts  rt= 97 pt=94 lt=83
# 0
# 5
# 10
# run time = 132.33405351638794 sec
# new opts  rt= 97 pt=94 lt=84
# 0
# 5
# 10
# run time = 132.78198957443237 sec
# new opts  rt= 97 pt=95 lt=80
# 0
# 5
# 10
# run time = 132.893079996109 sec
# new opts  rt= 97 pt=95 lt=81
# 0
# 5
# 10
# run time = 132.39379262924194 sec
# new opts  rt= 97 pt=95 lt=82
# 0
# 5
# 10
# run time = 132.46520042419434 sec
# new opts  rt= 97 pt=95 lt=83
# 0
# 5
# 10
# run time = 132.4896275997162 sec
# new opts  rt= 97 pt=95 lt=84
# 0
# 5
# 10
# run time = 132.48504877090454 sec
# new opts  rt= 97 pt=96 lt=80
# 0
# 5
# 10
# run time = 133.45482230186462 sec
# new opts  rt= 97 pt=96 lt=81
# 0
# 5
# 10
# run time = 131.96160554885864 sec
# new opts  rt= 97 pt=96 lt=82
# 0
# 5
# 10
# run time = 132.93201422691345 sec
# new opts  rt= 97 pt=96 lt=83
# 0
# 5
# 10
# run time = 133.73543167114258 sec
# new opts  rt= 97 pt=96 lt=84
# 0
# 5
# 10
# run time = 133.2769935131073 sec
# new opts  rt= 97 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.02304196357727 sec
# new opts  rt= 97 pt=97 lt=81
# 0
# 5
# 10
# run time = 133.54626536369324 sec
# new opts  rt= 97 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.03741979599 sec
# new opts  rt= 97 pt=97 lt=83
# 0
# 5
# 10
# run time = 132.49632692337036 sec
# new opts  rt= 97 pt=97 lt=84
# 0
# 5
# 10
# run time = 132.76838088035583 sec
# new opts  rt= 97 pt=98 lt=80
# 0
# 5
# 10
# run time = 132.3318154811859 sec
# new opts  rt= 97 pt=98 lt=81
# 0
# 5
# 10
# run time = 131.64181208610535 sec
# new opts  rt= 97 pt=98 lt=82
# 0
# 5
# 10
# run time = 133.6631474494934 sec
# new opts  rt= 97 pt=98 lt=83
# 0
# 5
# 10
# run time = 133.38024425506592 sec
# new opts  rt= 97 pt=98 lt=84
# 0
# 5
# 10
# run time = 133.37333822250366 sec
# new opts  rt= 97 pt=99 lt=80
# 0
# 5
# 10
# run time = 132.2720856666565 sec
# new opts  rt= 97 pt=99 lt=81
# 0
# 5
# 10
# run time = 132.4188358783722 sec
# new opts  rt= 97 pt=99 lt=82
# 0
# 5
# 10
# run time = 134.07038235664368 sec
# new opts  rt= 97 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.8415811061859 sec
# new opts  rt= 97 pt=99 lt=84
# 0
# 5
# 10
# run time = 134.32978534698486 sec
# new opts  rt= 98 pt=90 lt=80
# 0
# 5
# 10
# run time = 132.50789308547974 sec
# new opts  rt= 98 pt=90 lt=81
# 0
# 5
# 10
# run time = 132.64179491996765 sec
# new opts  rt= 98 pt=90 lt=82
# 0
# 5
# 10
# run time = 131.08702397346497 sec
# new opts  rt= 98 pt=90 lt=83
# 0
# 5
# 10
# run time = 131.61563086509705 sec
# new opts  rt= 98 pt=90 lt=84
# 0
# 5
# 10
# run time = 132.27595782279968 sec
# new opts  rt= 98 pt=91 lt=80
# 0
# 5
# 10
# run time = 132.16278314590454 sec
# new opts  rt= 98 pt=91 lt=81
# 0
# 5
# 10
# run time = 132.60751128196716 sec
# new opts  rt= 98 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.74794459342957 sec
# new opts  rt= 98 pt=91 lt=83
# 0
# 5
# 10
# run time = 133.11088728904724 sec
# new opts  rt= 98 pt=91 lt=84
# 0
# 5
# 10
# run time = 133.28828835487366 sec
# new opts  rt= 98 pt=92 lt=80
# 0
# 5
# 10
# run time = 132.66324925422668 sec
# new opts  rt= 98 pt=92 lt=81
# 0
# 5
# 10
# run time = 135.43313884735107 sec
# new opts  rt= 98 pt=92 lt=82
# 0
# 5
# 10
# run time = 133.06688022613525 sec
# new opts  rt= 98 pt=92 lt=83
# 0
# 5
# 10
# run time = 133.61197233200073 sec
# new opts  rt= 98 pt=92 lt=84
# 0
# 5
# 10
# run time = 132.7762930393219 sec
# new opts  rt= 98 pt=93 lt=80
# 0
# 5
# 10
# run time = 130.90859150886536 sec
# new opts  rt= 98 pt=93 lt=81
# 0
# 5
# 10
# run time = 133.97826170921326 sec
# new opts  rt= 98 pt=93 lt=82
# 0
# 5
# 10
# run time = 134.73362350463867 sec
# new opts  rt= 98 pt=93 lt=83
# 0
# 5
# 10
# run time = 132.89621782302856 sec
# new opts  rt= 98 pt=93 lt=84
# 0
# 5
# 10
# run time = 133.3501636981964 sec
# new opts  rt= 98 pt=94 lt=80
# 0
# 5
# 10
# run time = 132.75438570976257 sec
# new opts  rt= 98 pt=94 lt=81
# 0
# 5
# 10
# run time = 131.89057040214539 sec
# new opts  rt= 98 pt=94 lt=82
# 0
# 5
# 10
# run time = 132.8313090801239 sec
# new opts  rt= 98 pt=94 lt=83
# 0
# 5
# 10
# run time = 133.6978280544281 sec
# new opts  rt= 98 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.49691319465637 sec
# new opts  rt= 98 pt=95 lt=80
# 0
# 5
# 10
# run time = 133.67043828964233 sec
# new opts  rt= 98 pt=95 lt=81
# 0
# 5
# 10
# run time = 133.2796492576599 sec
# new opts  rt= 98 pt=95 lt=82
# 0
# 5
# 10
# run time = 134.66598200798035 sec
# new opts  rt= 98 pt=95 lt=83
# 0
# 5
# 10
# run time = 132.653790473938 sec
# new opts  rt= 98 pt=95 lt=84
# 0
# 5
# 10
# run time = 131.73118448257446 sec
# new opts  rt= 98 pt=96 lt=80
# 0
# 5
# 10
# run time = 132.4191381931305 sec
# new opts  rt= 98 pt=96 lt=81
# 0
# 5
# 10
# run time = 132.40975904464722 sec
# new opts  rt= 98 pt=96 lt=82
# 0
# 5
# 10
# run time = 132.13448858261108 sec
# new opts  rt= 98 pt=96 lt=83
# 0
# 5
# 10
# run time = 133.2004919052124 sec
# new opts  rt= 98 pt=96 lt=84
# 0
# 5
# 10
# run time = 132.85717797279358 sec
# new opts  rt= 98 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.2608036994934 sec
# new opts  rt= 98 pt=97 lt=81
# 0
# 5
# 10
# run time = 131.77879786491394 sec
# new opts  rt= 98 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.04645562171936 sec
# new opts  rt= 98 pt=97 lt=83
# 0
# 5
# 10
# run time = 131.88879466056824 sec
# new opts  rt= 98 pt=97 lt=84
# 0
# 5
# 10
# run time = 132.9234266281128 sec
# new opts  rt= 98 pt=98 lt=80
# 0
# 5
# 10
# run time = 134.14562559127808 sec
# new opts  rt= 98 pt=98 lt=81
# 0
# 5
# 10
# run time = 132.04766154289246 sec
# new opts  rt= 98 pt=98 lt=82
# 0
# 5
# 10
# run time = 134.33448266983032 sec
# new opts  rt= 98 pt=98 lt=83
# 0
# 5
# 10
# run time = 133.12880635261536 sec
# new opts  rt= 98 pt=98 lt=84
# 0
# 5
# 10
# run time = 133.37525081634521 sec
# new opts  rt= 98 pt=99 lt=80
# 0
# 5
# 10
# run time = 133.44214367866516 sec
# new opts  rt= 98 pt=99 lt=81
# 0
# 5
# 10
# run time = 133.47443842887878 sec
# new opts  rt= 98 pt=99 lt=82
# 0
# 5
# 10
# run time = 133.1977024078369 sec
# new opts  rt= 98 pt=99 lt=83
# 0
# 5
# 10
# run time = 133.90695071220398 sec
# new opts  rt= 98 pt=99 lt=84
# 0
# 5
# 10
# run time = 133.4256362915039 sec
# new opts  rt= 99 pt=90 lt=80
# 0
# 5
# 10
# run time = 132.72407293319702 sec
# new opts  rt= 99 pt=90 lt=81
# 0
# 5
# 10
# run time = 133.17553234100342 sec
# new opts  rt= 99 pt=90 lt=82
# 0
# 5
# 10
# run time = 133.79771661758423 sec
# new opts  rt= 99 pt=90 lt=83
# 0
# 5
# 10
# run time = 131.7058925628662 sec
# new opts  rt= 99 pt=90 lt=84
# 0
# 5
# 10
# run time = 132.78860688209534 sec
# new opts  rt= 99 pt=91 lt=80
# 0
# 5
# 10
# run time = 131.5793433189392 sec
# new opts  rt= 99 pt=91 lt=81
# 0
# 5
# 10
# run time = 131.94146585464478 sec
# new opts  rt= 99 pt=91 lt=82
# 0
# 5
# 10
# run time = 133.1594603061676 sec
# new opts  rt= 99 pt=91 lt=83
# 0
# 5
# 10
# run time = 132.38021326065063 sec
# new opts  rt= 99 pt=91 lt=84
# 0
# 5
# 10
# run time = 131.79052877426147 sec
# new opts  rt= 99 pt=92 lt=80
# 0
# 5
# 10
# run time = 133.44816851615906 sec
# new opts  rt= 99 pt=92 lt=81
# 0
# 5
# 10
# run time = 132.81481528282166 sec
# new opts  rt= 99 pt=92 lt=82
# 0
# 5
# 10
# run time = 133.8287103176117 sec
# new opts  rt= 99 pt=92 lt=83
# 0
# 5
# 10
# run time = 132.0361623764038 sec
# new opts  rt= 99 pt=92 lt=84
# 0
# 5
# 10
# run time = 133.56628370285034 sec
# new opts  rt= 99 pt=93 lt=80
# 0
# 5
# 10
# run time = 133.00175309181213 sec
# new opts  rt= 99 pt=93 lt=81
# 0
# 5
# 10
# run time = 132.49412560462952 sec
# new opts  rt= 99 pt=93 lt=82
# 0
# 5
# 10
# run time = 133.1465036869049 sec
# new opts  rt= 99 pt=93 lt=83
# 0
# 5
# 10
# run time = 134.19420218467712 sec
# new opts  rt= 99 pt=93 lt=84
# 0
# 5
# 10
# run time = 133.3777928352356 sec
# new opts  rt= 99 pt=94 lt=80
# 0
# 5
# 10
# run time = 133.0896394252777 sec
# new opts  rt= 99 pt=94 lt=81
# 0
# 5
# 10
# run time = 133.6217086315155 sec
# new opts  rt= 99 pt=94 lt=82
# 0
# 5
# 10
# run time = 133.08972454071045 sec
# new opts  rt= 99 pt=94 lt=83
# 0
# 5
# 10
# run time = 132.8211851119995 sec
# new opts  rt= 99 pt=94 lt=84
# 0
# 5
# 10
# run time = 133.73274946212769 sec
# new opts  rt= 99 pt=95 lt=80
# 0
# 5
# 10
# run time = 132.33054280281067 sec
# new opts  rt= 99 pt=95 lt=81
# 0
# 5
# 10
# run time = 133.04913091659546 sec
# new opts  rt= 99 pt=95 lt=82
# 0
# 5
# 10
# run time = 133.28874397277832 sec
# new opts  rt= 99 pt=95 lt=83
# 0
# 5
# 10
# run time = 132.77070379257202 sec
# new opts  rt= 99 pt=95 lt=84
# 0
# 5
# 10
# run time = 133.92736506462097 sec
# new opts  rt= 99 pt=96 lt=80
# 0
# 5
# 10
# run time = 131.98926901817322 sec
# new opts  rt= 99 pt=96 lt=81
# 0
# 5
# 10
# run time = 132.57816433906555 sec
# new opts  rt= 99 pt=96 lt=82
# 0
# 5
# 10
# run time = 134.00298070907593 sec
# new opts  rt= 99 pt=96 lt=83
# 0
# 5
# 10
# run time = 132.03430366516113 sec
# new opts  rt= 99 pt=96 lt=84
# 0
# 5
# 10
# run time = 133.49165105819702 sec
# new opts  rt= 99 pt=97 lt=80
# 0
# 5
# 10
# run time = 133.78985691070557 sec
# new opts  rt= 99 pt=97 lt=81
# 0
# 5
# 10
# run time = 133.34970378875732 sec
# new opts  rt= 99 pt=97 lt=82
# 0
# 5
# 10
# run time = 133.7134346961975 sec
# new opts  rt= 99 pt=97 lt=83
# 0
# 5
# 10
# run time = 133.43863201141357 sec
# new opts  rt= 99 pt=97 lt=84
# 0
# 5
# 10
# run time = 133.1975119113922 sec
# new opts  rt= 99 pt=98 lt=80
# 0
# 5
# 10
# run time = 132.81432628631592 sec
# new opts  rt= 99 pt=98 lt=81
# 0
# 5
# 10
# run time = 133.048033952713 sec
# new opts  rt= 99 pt=98 lt=82
# 0
# 5
# 10
# run time = 134.27222514152527 sec
# new opts  rt= 99 pt=98 lt=83
# 0
# 5
# 10
# run time = 133.33564639091492 sec
# new opts  rt= 99 pt=98 lt=84
# 0
# 5
# 10
# run time = 134.23212003707886 sec
# new opts  rt= 99 pt=99 lt=80
# 0
# 5
# 10
# run time = 133.3541910648346 sec
# new opts  rt= 99 pt=99 lt=81
# 0
# 5
# 10
# run time = 132.85019755363464 sec
# new opts  rt= 99 pt=99 lt=82
# 0
# 5
# 10
# run time = 133.69164299964905 sec
# new opts  rt= 99 pt=99 lt=83
# 0
# 5
# 10
# run time = 132.27495861053467 sec
# new opts  rt= 99 pt=99 lt=84
# 0
# 5
# 10
# run time = 133.67949151992798 sec

# %%
with open('hpo.pkl', 'wb') as f:
    pickle.dump(hpo, f)

# %%
min_fns = np.mean(hpo[0]["fns"])
min_fps = np.mean(hpo[0]["fps"])
min_fns = np.mean(hpo[0]["fns"])
min_fps = np.mean(hpo[0]["fps"])
for i in hpo:
    if np.mean(i["fns"])<min_fns:
        min_fns = np.mean(i["fns"])
        min_fns_opts = i
    if np.mean(i["fps"])<min_fps:
        min_fps = np.mean(i["fps"])
        min_fps_opts = i

# %%
min_fns_opts
# Out:
# {'rt': 90,
#  'pt': 92,
#  'lt': 81,
#  'fns': [0.4,
#   0.5,
#   0.3,
#   1.0,
#   1.1,
#   1.3,
#   0.4,
#   0.8,
#   0.7,
#   0.8,
#   0.2,
#   0.3,
#   0.2,
#   0.8,
#   0.2],
#  'fps': [5.5,
#   6.6,
#   6.2,
#   6.3,
#   5.5,
#   6.7,
#   7.0,
#   6.1,
#   7.4,
#   6.7,
#   7.0,
#   7.2,
#   7.0,
#   5.8,
#   6.7]}

# %%
min_fps_opts
# Out:
# {'rt': 99,
#  'pt': 98,
#  'lt': 82,
#  'fns': [1.4,
#   1.2,
#   1.6,
#   1.5,
#   1.2,
#   2.4,
#   1.5,
#   1.4,
#   1.0,
#   1.2,
#   1.7,
#   1.5,
#   1.4,
#   1.6,
#   1.4],
#  'fps': [5.2,
#   5.7,
#   6.2,
#   5.0,
#   4.9,
#   4.5,
#   4.5,
#   5.3,
#   4.9,
#   4.8,
#   4.4,
#   4.6,
#   4.2,
#   4.3,
#   5.0]}

# %%
plt.figure(figsize=(8,6))
plt.hist(fns, bins=10, alpha=0.5, label="data1", density=False)
True

# %%
plt.figure(figsize=(8,6))
plt.hist(fps, bins=10, alpha=0.5, label="data1", density=False)
True

# %%
#0.71 no ES th
#0.69 boost 1 size =5
np.mean(fns)

# %%
np.std(fns)

# %%
np.mean(fps)

# %%
np.std(fps)

# %%
with open('similarity_fns_fps_noauthors_ratio_thold95.pkl', 'wb') as f:
    pickle.dump({"fns":fns,"fps":fps}, f)
